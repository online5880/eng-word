# %% [markdown]
# # json 불러오기

# %%
import json

file_path = r"C:\Users\user\Desktop\eng-word\utils\json_words\clustered_wordbook.json"
with open(file_path, encoding="utf-8") as file:
    data = json.load(file)

data
# Out:
# {'category_0': [{'단어': 'attractive',
#    '단어 뜻': ['매력적인'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The main character of the movie is an attractive man.',
#      '한글': '그 영화 주인공은 매력적인 남성이다.'}]},
#   {'단어': 'handsome',
#    '단어 뜻': ['잘생긴'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Tony is handsome.', '한글': 'Tony는 잘생겼어.'},
#     {'영문': 'He is tall and handsome.', '한글': '그는 키가 크고 잘생겼어.'},
#     {'영문': 'Ryan is very handsome.', '한글': 'Ryan은 무척 잘생겼어'},
#     {'영문': 'He’s handsome.', '한글': '그는 잘생겼어.'}]},
#   {'단어': 'lovely',
#    '단어 뜻': ['사랑스\n러운', '사랑스러운'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Jenny is so lovely.', '한글': 'Jenny는 무척 사랑스러워.'},
#     {'영문': 'The island is famous for a lovely white lighthouse.',
#      '한글': '그 섬은 예쁜 하얀 등대로 유명하다.'},
#     {'영문': 'Isn’t she really lovely?', '한글': '그녀는 정말 사랑스럽지 않아요?'}]},
#   {'단어': 'wonderful',
#    '단어 뜻': ['아주 좋은'],
#    '품사': '',
#    '예문': [{'영문': 'It is a wonderful story.', '한글': '그것은 아주 좋은 이야기야.'}]},
#   {'단어': 'excellent',
#    '단어 뜻': ['훌륭한', '아주 좋은'],
#    '품사': '',
#    '예문': [{'영문': 'Mom’s cake was excellent.', '한글': '엄마의 케이크는 훌륭했다.'},
#     {'영문': 'This steak is excellent.', '한글': '이 스테이크는 맛이 아주 좋아.'}]},
#   {'단어': 'incredible',
#    '단어 뜻': ['믿을 수 없는'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Usain Bolt crossed the finish line at an incredible speed.',
#      '한글': '우사인 볼트는 놀라운 속도로 결승선을 통과했다.'}]},
#   {'단어': 'beautiful',
#    '단어 뜻': ['아름다운'],
#    '품사': '',
#    '예문': [{'영문': 'These flowers are beautiful.', '한글': '이 꽃들은 아름답다.'},
#     {'영문': 'She is beautiful.', '한글': '그녀는 아름다워.'},
#     {'영문': 'These flowers are beautiful.', '한글': '이 꽃들은 아름다워.'},
#     {'영문': 'They’re beautiful.', '한글': '그들은 아름다워.'}]},
#   {'단어': 'extraordinary',
#    '단어 뜻': ['놀라운, 기이한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'To draw pictures at his young age is something extraordinary.',
#      '한글': '그가 그런 어린 나이에 그림을 그리는 것은 놀라운 일이다.'}]},
#   {'단어': 'fine',
#    '단어 뜻': ['좋은', '벌금을 물리다'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I’m fine. Thank you.', '한글': '난 좋아요. 고마워요.'},
#     {'영문': 'I was fined for parking.', '한글': '주차 때문에 벌금을 물었어.'}]},
#   {'단어': 'cute',
#    '단어 뜻': ['귀여운'],
#    '품사': '',
#    '예문': [{'영문': 'My brother is cute.', '한글': '내 남동생은 귀엽다.'},
#     {'영문': 'She’s cute.', '한글': '그녀는 귀여워.'}]},
#   {'단어': 'great',
#    '단어 뜻': ['정말 좋은', '훌륭한'],
#    '품사': '',
#    '예문': [{'영문': 'I’m great.', '한글': '나는 정말 좋아.'},
#     {'영문': 'He is a great scientist.', '한글': '그는 훌륭한 과학자야.'}]},
#   {'단어': 'terrific',
#    '단어 뜻': ['아주 멋진'],
#    '품사': '형용사',
#    '예문': [{'영문': 'What a terrific idea!', '한글': '아주 멋진 생각이다!'}]},
#   {'단어': 'okay',
#    '단어 뜻': ['좋아'],
#    '품사': '',
#    '예문': [{'영문': 'I’m okay.', '한글': '나는 괜찮아.'}]},
#   {'단어': 'amazing',
#    '단어 뜻': ['놀라운'],
#    '품사': '',
#    '예문': [{'영문': 'The night view is amazing from the building.',
#      '한글': '그 빌딩의 야경은 놀랍다.'},
#     {'영문': 'The Amazon is amazing.', '한글': '아마존은 놀라워.'}]},
#   {'단어': 'pretty',
#    '단어 뜻': ['예쁜'],
#    '품사': '형용사',
#    '예문': [{'영문': 'You look pretty.', '한글': '너 예뻐 보여.'},
#     {'영문': 'You’re pretty.', '한글': '너는 예뻐.'}]},
#   {'단어': 'good',
#    '단어 뜻': ['기분이 좋은'],
#    '품사': '',
#    '예문': [{'영문': 'They’re good.', '한글': '그들은 기분이 좋아.'}]},
#   {'단어': 'perfect',
#    '단어 뜻': ['완벽한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Practice makes perfect.', '한글': '연습하면 완벽해져.'}]},
#   {'단어': 'elegant',
#    '단어 뜻': ['우아한, 품위 있는'],
#    '품사': 'adj',
#    '예문': [{'영문': 'My mother is elegant and kind',
#      '한글': '우리 엄마는 우아하고 친절하시다.'}]},
#   {'단어': 'impression',
#    '단어 뜻': ['인상'],
#    '품사': 'n.',
#    '예문': [{'영문': 'My first impression of a new classmate was good.',
#      '한글': '새 전학생에 대한 내 첫인상은 좋았다.'}]},
#   {'단어': 'so',
#    '단어 뜻': ['그래서', '매우'],
#    '품사': 'conj.',
#    '예문': [{'영문': 'I’m tired, so I can’t go with you.',
#      '한글': '나는 피곤해서 너와 함께 갈 수 없다.'},
#     {'영문': 'The teddy bear is so big.', '한글': '그 곰돌이는 매우 커.'}]},
#   {'단어': 'see',
#    '단어 뜻': ['보다'],
#    '품사': '',
#    '예문': [{'영문': 'They see the rabbits.', '한글': '그들은 토끼를 본다.'},
#     {'영문': 'Can you see the top of the mountain?',
#      '한글': '너는 그 산 꼭대기를 볼 수 있니?'}]},
#   {'단어': 'enough',
#    '단어 뜻': ['충분한'],
#    '품사': '',
#    '예문': [{'영문': 'That’s enough.', '한글': '그걸로 충분해.'},
#     {'영문': 'I saved enough money to buy those shoes.',
#      '한글': '저 신발을 살 만큼 충분한 돈을 모았어.'}]},
#   {'단어': 'really',
#    '단어 뜻': ['정말로'],
#    '품사': '',
#    '예문': [{'영문': 'Is it really true?', '한글': '그거 정말로 사실이야?'},
#     {'영문': 'I really want to go on a picnic.', '한글': '나는 정말로 소풍 가고 싶어.'}]},
#   {'단어': 'please',
#    '단어 뜻': ['제발, 부디'],
#    '품사': '',
#    '예문': [{'영문': 'Please wash your hands.', '한글': '손을 씻으세요.'}]},
#   {'단어': 'must',
#    '단어 뜻': ['~해야 하\n다'],
#    '품사': '동사',
#    '예문': [{'영문': 'You must wake up!', '한글': '너는 일어나야 해!'}]},
#   {'단어': 'take care',
#    '단어 뜻': ['안녕, 잘 가'],
#    '품사': '',
#    '예문': [{'영문': 'Take care.', '한글': '안녕, 잘 가.'}]},
#   {'단어': 'admire',
#    '단어 뜻': ['감탄하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'I admired her brilliant paintings.',
#      '한글': '나는 그녀의 뛰어난 그림에 감탄했다.'}]},
#   {'단어': 'enjoy',
#    '단어 뜻': ['즐기다'],
#    '품사': '',
#    '예문': [{'영문': 'They are enjoying their vacation.', '한글': '그들은 휴가를 즐기고 있어.'},
#     {'영문': 'My sister knows how to enjoy life.',
#      '한글': '우리 언니는 인생을 즐길 줄 알아.'}]},
#   {'단어': 'delicious',
#    '단어 뜻': ['맛있는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'It looks delicious, doesn’t it?', '한글': '그건 맛있어 보이지 않나요?'},
#     {'영문': 'They look delicious.', '한글': '그것들은 맛있어 보여.'}]},
#   {'단어': 'way',
#    '단어 뜻': ['길'],
#    '품사': '명사',
#    '예문': [{'영문': 'Go along this way.', '한글': '이쪽 길을 따라가세요.'}]},
#   {'단어': 'blush',
#    '단어 뜻': ['얼굴을 붉히다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I blush when I’m happy.', '한글': '나는 기쁠 때 얼굴이 빨개져.'}]},
#   {'단어': 'spicy',
#    '단어 뜻': ['매콤한'],
#    '품사': '',
#    '예문': [{'영문': 'This food is too spicy.', '한글': '이 음식은 너무 매워.'}]},
#   {'단어': 'pleased',
#    '단어 뜻': ['기쁜'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Harry looks so pleased.', '한글': 'Harry는 무척 기쁜 것 같아.'},
#     {'영문': 'I was pleased at his gift.', '한글': '나는 그의 선물을 받고 기뻤어.'}]},
#   {'단어': 'proper',
#    '단어 뜻': ['적절한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The plants are going to be put in their proper places the next day.',
#      '한글': '그 식물들은'}]},
#   {'단어': 'quite',
#    '단어 뜻': ['꽤'],
#    '품사': 'adv.',
#    '예문': [{'영문': 'What he did with his wealth was quite unique.',
#      '한글': '그가 자기 재산을 가지고 한 일은 꽤 독특했다.'}]},
#   {'단어': 'tight',
#    '단어 뜻': ['꽉 끼는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The tights are too tight.', '한글': '타이츠가 너무 꽉 끼어.'}]},
#   {'단어': 'promise',
#    '단어 뜻': ['약속하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I promise I’ll come back.', '한글': '돌아올 것을 약속할게.'},
#     {'영문': 'Mom promised to buy a smart phone for me.',
#      '한글': '엄마는 내게 스마트폰을 사 주기로 약속하셨어.'}]},
#   {'단어': 'certain',
#    '단어 뜻': ['확신하는, 확\n실한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I feel certain he will win.', '한글': '그가 이길 거라는 확신이 들어.'}]},
#   {'단어': 'thank',
#    '단어 뜻': ['감사하다', '(~ 고마워\n하다'],
#    '품사': '',
#    '예문': [{'영문': 'Thank you very much.', '한글': '매우 고마워요.'},
#     {'영문': 'Thank you for the present.', '한글': '선물 고마워'}]},
#   {'단어': 'as',
#    '단어 뜻': ['~만큼'],
#    '품사': '',
#    '예문': [{'영문': 'Amy runs as fast as Emma.', '한글': 'Amy는 Emma만큼 빨리 달려.'}]},
#   {'단어': 'closely',
#    '단어 뜻': ['자세히'],
#    '품사': 'adv.',
#    '예문': [{'영문': "Look at the elephant's nose closely in the picture.",
#      '한글': '사진 속 코끼리의 코를 자세히 봐라.'}]},
#   {'단어': 'finally',
#    '단어 뜻': ['마침내'],
#    '품사': 'adv.',
#    '예문': [{'영문': 'Finally, Becky invented paper that can glow in the dark.',
#      '한글': '마침내, Becky는 어두운 곳에서 빛나는 종이를 발명했다.'}]},
#   {'단어': 'able',
#    '단어 뜻': ['~할 수 있는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I am able to play tennis.', '한글': '나는 테니스를 칠 수 있어.'}]},
#   {'단어': 'ill',
#    '단어 뜻': ['아픈'],
#    '품사': '',
#    '예문': [{'영문': 'My grandma is ill.', '한글': '우리 할머니는 아프시다.'},
#     {'영문': 'What’s wrong? You look ill.', '한글': '무슨 일 있니? 너 아파 보여.'}]},
#   {'단어': 'through',
#    '단어 뜻': ['~ 을 통해'],
#    '품사': '전치사',
#    '예문': [{'영문': 'Water goes through this pipe.', '한글': '물이 이 관을 통해 지나가.'}]},
#   {'단어': 'best',
#    '단어 뜻': ['가장좋은', '최고의'],
#    '품사': '형용사',
#    '예문': [{'영문': 'It’s the best plant for your health.',
#      '한글': '그것은 네 건강에 가장 좋은 식물이야.'},
#     {'영문': 'Who is the best actor?', '한글': '누가 최고의 배우이니?'}]},
#   {'단어': 'better',
#    '단어 뜻': ['더 좋은'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Your bike is better than mine.',
#      '한글': '네 자전거가 내 것보다 저 좋구나.'}]},
#   {'단어': 'very',
#    '단어 뜻': ['매우, 아주'],
#    '품사': '부사',
#    '예문': [{'영문': 'The piano is very big.', '한글': '그 피아노는 아주 커.'}]},
#   {'단어': 'then',
#    '단어 뜻': ['그 다음에'],
#    '품사': '부사',
#    '예문': [{'영문': 'Then, what piece should I move?',
#      '한글': '그 다음에 나는 무슨 말을 옮겨야 할까?'}]},
#   {'단어': 'next',
#    '단어 뜻': ['다음의'],
#    '품사': '',
#    '예문': [{'영문': 'My birthday is next Thursday.', '한글': '내 생일은 다음 목요일이야.'}]},
#   {'단어': 'idea',
#    '단어 뜻': ['생각'],
#    '품사': '',
#    '예문': [{'영문': 'Matt has a good idea.', '한글': '맷에게 좋은 생각이 있다.'},
#     {'영문': 'That’s a good idea.', '한글': '좋은 생각이야.'}]},
#   {'단어': 'natural',
#    '단어 뜻': ['자연의'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Environmental pollution is a cause of most of the natural disasters.',
#      '한글': '환경 오염은 대부분의 자연 재해의 한 원인이다.'}]},
#   {'단어': 'classic',
#    '단어 뜻': ['고전적인'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'My mother likes the classic film, The Sound of Music.',
#      '한글': '우리 엄마는 사운드 오브 뮤직이라는 고전 영화를 좋아하신다.'}]},
#   {'단어': 'glad',
#    '단어 뜻': ['반가운', '반가운, 기쁜'],
#    '품사': '',
#    '예문': [{'영문': 'Glad to meet you.', '한글': '만나서 반가워요.'},
#     {'영문': 'I’m glad to meet you.', '한글': '만나서 반가워요.'}]},
#   {'단어': 'how',
#    '단어 뜻': ['어떻게'],
#    '품사': '',
#    '예문': [{'영문': 'How are you?', '한글': '너는 어떻게 지내니?'}]},
#   {'단어': 'well',
#    '단어 뜻': ['잘'],
#    '품사': '',
#    '예문': [{'영문': 'Well done.', '한글': '잘 했어.'}]},
#   {'단어': 'mind',
#    '단어 뜻': ['꺼리다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Do you mind if I kill this bug?',
#      '한글': '내가 이 벌레를 죽여도 될까?'}]},
#   {'단어': 'due',
#    '단어 뜻': ['기일이 다 된'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The final report is due at the end of the month.',
#      '한글': '최종 보고서는 그 달 말이 마감이다.'}]},
#   {'단어': 'ready',
#    '단어 뜻': ['준비가 된'],
#    '품사': '',
#    '예문': [{'영문': 'I’m ready.', '한글': '나는 준비가 됐어.'}]},
#   {'단어': 'special',
#    '단어 뜻': ['특별한'],
#    '품사': '형용상',
#    '예문': [{'영문': 'You are very special to me.', '한글': '너는 내게 매우 특별해.'}]},
#   {'단어': 'exact',
#    '단어 뜻': ['정확한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The exact time is 1:51 p.m.',
#      '한글': '정확한 시각은 오후 1시 51분이야.'}]},
#   {'단어': 'hot',
#    '단어 뜻': ['더운'],
#    '품사': '',
#    '예문': [{'영문': 'It’s hot.', '한글': '더워.'}]},
#   {'단어': 'reasonable',
#    '단어 뜻': ['(가격이) 적정한'],
#    '품사': 'adj.',
#    '예문': [{'영문': "The rental fee of ski boots wasn't reasonable.",
#      '한글': '스키 부츠 대여료는 적당하지 않았다.'}]},
#   {'단어': 'sick',
#    '단어 뜻': ['아픈'],
#    '품사': '',
#    '예문': [{'영문': 'I’m sick.', '한글': '나는 아파.'},
#     {'영문': 'I am sick with a cold.', '한글': '나는 감기에 걸려 아파.'},
#     {'영문': 'You are sick.', '한글': '너는 아프구나.'}]},
#   {'단어': 'imagine',
#    '단어 뜻': ['상상하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I can’t imagine the world without her.',
#      '한글': '나는 그녀가 없는 세상을 상상할 수 없어.'}]},
#   {'단어': 'sure',
#    '단어 뜻': ['물론'],
#    '품사': '',
#    '예문': [{'영문': 'Sure, I can.', '한글': '물론 할 수 있어.'}]},
#   {'단어': 'here',
#    '단어 뜻': ['여기에'],
#    '품사': '서',
#    '예문': [{'영문': 'Let’s have dinner here.', '한글': '여기에서 저녁 식사를 하자.'}]},
#   {'단어': 'there',
#    '단어 뜻': ['거기에'],
#    '품사': '서',
#    '예문': [{'영문': 'Let’s meet there.', '한글': '거기에서 만나자.'}]}],
#  'category_1': [{'단어': 'clever',
#    '단어 뜻': ['영리한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The clever Robin Hood escaped from the bad guys.',
#      '한글': '영리한 로빈 후드는 나쁜 악당들의 추적을 따돌렸다.'}]},
#   {'단어': 'smart',
#    '단어 뜻': ['영리한', '똑똑한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'It’s about a smart girl.', '한글': '그것은 한 영리한 소녀에 관한 것이에요.'},
#     {'영문': 'My dog is smart.', '한글': '우리 개는 똑똑해.'},
#     {'영문': 'She is smart.', '한글': '그녀는 똑똑해.'}]},
#   {'단어': 'wise',
#    '단어 뜻': ['현명한', '지혜로운,\n현명한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'That was a wise choice.', '한글': '그것은 현명한 선택이었어.'},
#     {'영문': 'Europeans believe that owls are wise.',
#      '한글': '유럽 사람들은 올빼미가 지혜롭다고 믿어.'}]},
#   {'단어': 'skillful',
#    '단어 뜻': ['숙련된, 솜씨 좋은'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The lawyer is skillful at dealing with business law.',
#      '한글': '그 변호사는 상법을 다루는 데 능숙하다.'}]}],
#  'category_2': [{'단어': 'dull',
#    '단어 뜻': ['재미없는, 지루한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'He is a nice but dull man.', '한글': '그는 친절하지만 지루한 남자이다.'}]},
#   {'단어': 'boring',
#    '단어 뜻': ['지루한', '지겨운'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Bowling is boring.', '한글': '볼링은 지루해.'},
#     {'영문': 'The book is boring.', '한글': '그 책은 지루해.'},
#     {'영문': 'I think this movie is boring.', '한글': '나는 이 영화가 지겹다고 생각해.'},
#     {'영문': 'This book is boring.', '한글': '이 책은 지루하다.'},
#     {'영문': 'I fell asleep because the movie was boring.',
#      '한글': '영화가 지루해서 나는 잠이 들었어.'}]},
#   {'단어': 'bored',
#    '단어 뜻': ['지루한'],
#    '품사': '',
#    '예문': [{'영문': 'I’m bored.', '한글': '나는 지루해.'}]},
#   {'단어': 'lazy',
#    '단어 뜻': ['게으른'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I am slow and lazy.', '한글': '나는 느리고 게을러.'},
#     {'영문': 'Please don’t be lazy about cleaning your room.',
#      '한글': '제발 네 방 청소하는 것에 게으르지 마.'}]},
#   {'단어': 'flat',
#    '단어 뜻': ['납작한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The shoes are flat.', '한글': '그 신발은 납작해.'}]},
#   {'단어': 'ugly',
#    '단어 뜻': ['못생긴'],
#    '품사': '형용사',
#    '예문': [{'영문': 'It’s a really ugly dog.', '한글': '그것은 정말로 못생긴 개야.'}]}],
#  'category_3': [{'단어': 'working',
#    '단어 뜻': ['성실한, 근면한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Coworkers in my company are hard-working.',
#      '한글': '우리 회사의 동료들은 성실하다.'}]},
#   {'단어': 'job',
#    '단어 뜻': ['일', '직업'],
#    '품사': '명사',
#    '예문': [{'영문': 'What’s your dream job?', '한글': '네가 하고 싶은 일은 뭐야?'},
#     {'영문': 'I love my job.', '한글': '나는 내 직업을 사랑해.'}]},
#   {'단어': 'employer',
#    '단어 뜻': ['고용주'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The employer has dismissed a lot of people because of the financial problem.',
#      '한글': '그 고용주는 자금난 때문에 많은 사람들을 해고했다.'}]},
#   {'단어': 'work',
#    '단어 뜻': ['일하다'],
#    '품사': '',
#    '예문': [{'영문': 'They are working in the office.',
#      '한글': '그들은 사무실에서 일하고 있어.'}]},
#   {'단어': 'duty',
#    '단어 뜻': ['의무'],
#    '품사': 'n.',
#    '예문': [{'영문': 'A basic duty of the people is paying taxes.',
#      '한글': '국민의 기본 의무는 세금을 납부하는 것이다.'}]},
#   {'단어': 'business',
#    '단어 뜻': ['사업'],
#    '품사': '명사',
#    '예문': [{'영문': 'She started the business last year.',
#      '한글': '그녀는 그 사업을 작년에 시작했어.'}]},
#   {'단어': 'hire',
#    '단어 뜻': ['고용하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Our factory has to hire more workers.',
#      '한글': '우리 공장은 더 많은 근로자를 고용해야 한다.'}]},
#   {'단어': 'labor',
#    '단어 뜻': ['노동'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Many people are against immoral child labor.',
#      '한글': '많은 사람들이 비윤리적인 어린이 노동에 반대한다.'}]},
#   {'단어': 'operate',
#    '단어 뜻': ['수술하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Dr. June is going to operate on my mother.',
#      '한글': 'June 의사 선생님께서 우리 엄마를 수술하실 것이다.'}]},
#   {'단어': 'company',
#    '단어 뜻': ['회사'],
#    '품사': '명사',
#    '예문': [{'영문': 'I worked for 5 years at the company.',
#      '한글': '나는 그 회사에서 5년간 근무했어.'}]},
#   {'단어': 'factory',
#    '단어 뜻': ['공장'],
#    '품사': '명사',
#    '예문': [{'영문': 'Sera works at the chocolate factory.',
#      '한글': '세라는 초콜릿 공장에서 근무해.'}]},
#   {'단어': 'staff',
#    '단어 뜻': ['직원'],
#    '품사': '',
#    '예문': [{'영문': 'The restaurant staff is kind.', '한글': '그 음식점 직원은 친절하다.'}]}],
#  'category_4': [{'단어': 'humorous',
#    '단어 뜻': ['재미있는'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'My science teacher is as humorous as a comedian.',
#      '한글': '우리 과학 선생님은 코미디언처럼 재미있다.'}]},
#   {'단어': 'funny',
#    '단어 뜻': ['웃기는', '재미있는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I think the picture is funny.', '한글': '나는 그 사진이 웃기다고 생각해.'},
#     {'영문': 'This story is really funny.', '한글': '이 이야기는 정말 재미있어.'}]},
#   {'단어': 'joke',
#    '단어 뜻': ['농담'],
#    '품사': '명사',
#    '예문': [{'영문': 'It’s nothing but a joke.', '한글': '그저 농담이야.'},
#     {'영문': 'I like telling jokes.', '한글': '나는 농담하는 것을 좋아해.'}]}],
#  'category_5': [{'단어': 'sincere',
#    '단어 뜻': ['진실된, 진심 어린'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'What should we do to have a sincere friendship?',
#      '한글': '진실된 우정을 얻기 위해 우리는 무엇을 해야 할까?'}]},
#   {'단어': 'honest',
#    '단어 뜻': ['솔직한', '정직한'],
#    '품사': '',
#    '예문': [{'영문': 'Bill is an honest boy.', '한글': '빌은 솔직한 소년이다.'},
#     {'영문': 'We’re honest.', '한글': '우리는 정직해.'}]},
#   {'단어': 'frankly',
#    '단어 뜻': ['솔직히'],
#    '품사': 'adv.',
#    '예문': [{'영문': 'We frankly admitted our mistake and apologized to him.',
#      '한글': '우리는 우리의 실수를 솔직히 인정하고 그에게 사과했다.'}]}],
#  'category_6': [{'단어': 'aunt',
#    '단어 뜻': ['이모, 고모'],
#    '품사': '명사',
#    '예문': [{'영문': 'Let me introduce my aunt.', '한글': '우리 이모(고모)를 소개해 드릴게요.'},
#     {'영문': 'This is my aunt.', '한글': '이 분은 우리 이모셔.'}]},
#   {'단어': 'cousin',
#    '단어 뜻': ['사촌'],
#    '품사': '명사',
#    '예문': [{'영문': 'They are my cousins.', '한글': '그들은 내 사촌들이야.'},
#     {'영문': 'My cousins are kind.', '한글': '내 사촌들은 친절하다.'},
#     {'영문': 'My favorite cousin came to my house.',
#      '한글': '내가 가장 좋아하는 사촌이 우리 집에 왔어.'},
#     {'영문': 'These are my cousins.', '한글': '이 사람들은 내 사촌들이야.'}]},
#   {'단어': 'ancestor',
#    '단어 뜻': ['조상'],
#    '품사': '명사',
#    '예문': [{'영문': 'Our ancestors used animal bones as weapons.',
#      '한글': '우리 조상들은 동물 뼈를 무기로 사용했어.'}]},
#   {'단어': 'brother',
#    '단어 뜻': ['남자 형제'],
#    '품사': '명사',
#    '예문': [{'영문': 'Do you have any brothers or sisters?',
#      '한글': '너는 남자 형제나 여자 형제가 있니?'},
#     {'영문': 'He is my brother.', '한글': '그는 내 오빠(형/남동생)야.'}]},
#   {'단어': 'daughter',
#    '단어 뜻': ['딸'],
#    '품사': '명사',
#    '예문': [{'영문': 'A king’s daughter is a princess.', '한글': '왕의 딸이 공주야.'},
#     {'영문': 'Do they have a daughter?', '한글': '그들은 딸이 한 명 있니?'}]},
#   {'단어': 'nephew',
#    '단어 뜻': ['조카'],
#    '품사': '명사',
#    '예문': [{'영문': 'A nephew is a son of your brother or sister.',
#      '한글': '조카는 여러분의 형제나 자매의 아들이에요.'}]},
#   {'단어': 'niece',
#    '단어 뜻': ['조카딸'],
#    '품사': '명사',
#    '예문': [{'영문': 'If he’s my uncle, I’m his niece.',
#      '한글': '만약 그가 내 삼촌이면, 나는 그의 조카딸이야.'}]},
#   {'단어': 'sister',
#    '단어 뜻': ['여자 형제', '언니, 누나, 여동\n생'],
#    '품사': '명사',
#    '예문': [{'영문': 'I have two brothers and one sister.',
#      '한글': '나는 두 명의 남자 형제와 한 명의 여자 형제가 있어.'},
#     {'영문': 'Is your sister cute?', '한글': '네 여동생은 귀엽니?'},
#     {'영문': 'She is my sister.', '한글': '그녀는 내 여동생(누나/언니)이야.'}]},
#   {'단어': 'child',
#    '단어 뜻': ['아이'],
#    '품사': '명사',
#    '예문': [{'영문': 'I only have one child.', '한글': '나는 아이가 한 명뿐이에요.'},
#     {'영문': 'Mary has a four-year-old child and two school-age children.',
#      '한글': 'Mary는 네 살 난 아이와 두 명의 학교에 다니는 나이의 아 이들이 있어.'}]},
#   {'단어': 'kid',
#    '단어 뜻': ['어린이', '아이'],
#    '품사': '',
#    '예문': [{'영문': 'Jack is a smart kid.', '한글': 'Jack은 영리한 아이야.'},
#     {'영문': 'The kid is cute.', '한글': '그 아이는 귀엽다.'}]},
#   {'단어': 'descendant',
#    '단어 뜻': ['자손, 후손'],
#    '품사': 'n.',
#    '예문': [{'영문': 'He said that he might be a descendant of a king.',
#      '한글': '그는 자신이 왕의 후손일지도 모른다고 말했다.'}]},
#   {'단어': 'dad',
#    '단어 뜻': ['아빠'],
#    '품사': '',
#    '예문': [{'영문': 'He is my dad.', '한글': '그는 우리 아빠야.'}]},
#   {'단어': 'mom',
#    '단어 뜻': ['엄마'],
#    '품사': '',
#    '예문': [{'영문': 'She is my mom.', '한글': '그녀는 우리 엄마야.'}]},
#   {'단어': 'family',
#    '단어 뜻': ['가족'],
#    '품사': '',
#    '예문': [{'영문': 'My family is always happy.', '한글': '우리 가족은 항상 행복해.'}]},
#   {'단어': 'father',
#    '단어 뜻': ['아버지'],
#    '품사': '',
#    '예문': [{'영문': 'This is my father.', '한글': '이 분은 우리 아빠셔.'}]},
#   {'단어': 'grandfather',
#    '단어 뜻': ['할아버지'],
#    '품사': '',
#    '예문': [{'영문': 'That is my grandfather.', '한글': '저 분은 우리 할아버지셔.'}]},
#   {'단어': 'grandmother',
#    '단어 뜻': ['할머니'],
#    '품사': '',
#    '예문': [{'영문': 'That is my grandmother.', '한글': '저 분은 우리 할머니셔.'}]},
#   {'단어': 'mother',
#    '단어 뜻': ['어머니'],
#    '품사': '',
#    '예문': [{'영문': 'This is my mother.', '한글': '이 분은 우리 엄마셔.'}]},
#   {'단어': 'parents',
#    '단어 뜻': ['부모님'],
#    '품사': '',
#    '예문': [{'영문': 'I love my parents.', '한글': '나는 우리 부모님을 사랑해.'}]},
#   {'단어': 'uncle',
#    '단어 뜻': ['삼촌, 아저씨'],
#    '품사': '',
#    '예문': [{'영문': 'This is my uncle.', '한글': '이 분은 우리 삼촌이셔.'}]},
#   {'단어': 'boy',
#    '단어 뜻': ['소년'],
#    '품사': '명사',
#    '예문': [{'영문': 'The boy is my brother.', '한글': '그 소년은 우리 형이야.'}]},
#   {'단어': 'nosy',
#    '단어 뜻': ['참견하기 좋아하는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The man is too nosy.', '한글': '그 남자는 참 참견하기 좋아해.'}]},
#   {'단어': 'hero',
#    '단어 뜻': ['영웅'],
#    '품사': '명사',
#    '예문': [{'영문': 'Super Dog Carlo is our hero.',
#      '한글': 'Super Dog Carlo는 우리의 영웅이야.'}]},
#   {'단어': 'relative',
#    '단어 뜻': ['친척'],
#    '품사': '명사',
#    '예문': [{'영문': 'A close relative lives in Namwon.',
#      '한글': '가까운 친척 한 분이 남원에 사셔.'},
#     {'영문': 'All his relatives came to the wedding.',
#      '한글': '그의 친척들 모두 결혼식에 왔어.'}]},
#   {'단어': 'stranger',
#    '단어 뜻': ['이상한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I saw a strange man at the park.',
#      '한글': '나는 공원에서 이상한 남자를 봤어.'}]},
#   {'단어': 'son',
#    '단어 뜻': ['아들'],
#    '품사': '명사',
#    '예문': [{'영문': 'They have a son and two daughters.',
#      '한글': '그들은 한 명의 아들과 두 명의 딸이 있어.'}]},
#   {'단어': 'scold',
#    '단어 뜻': ['야단치다', '혼내다'],
#    '품사': '',
#    '예문': [{'영문': 'The teacher is scolding Jake.', '한글': '선생님이 제이크를 야단치고 계신다.'},
#     {'영문': 'Don’t scold me too coldly.', '한글': '날 너무 차갑게 혼내지 마.'}]},
#   {'단어': 'passport',
#    '단어 뜻': ['여권'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Can I see your passport, please?',
#      '한글': '당신의 여권 좀 볼 수 있을까요?'}]},
#   {'단어': 'name',
#    '단어 뜻': ['이름'],
#    '품사': '',
#    '예문': [{'영문': 'Her name is Lucy.', '한글': '그녀의 이름은 루시야.'},
#     {'영문': 'My name is Jay.', '한글': '내 이름은 Jay야.'}]},
#   {'단어': 'baby',
#    '단어 뜻': ['아기'],
#    '품사': '',
#    '예문': [{'영문': 'He is a baby.', '한글': '그는 아기야.'}]},
#   {'단어': 'king',
#    '단어 뜻': ['왕'],
#    '품사': '',
#    '예문': [{'영문': 'Her father is a great king.', '한글': '그녀의 아버지는 훌륭한 왕이야.'}]},
#   {'단어': 'princess',
#    '단어 뜻': ['공주'],
#    '품사': '',
#    '예문': [{'영문': 'Isabella is a beautiful princess.',
#      '한글': 'Isabella는 아름다운 공주야.'}]},
#   {'단어': 'queen',
#    '단어 뜻': ['여왕, 왕비'],
#    '품사': '',
#    '예문': [{'영문': 'Her mother is a great queen.', '한글': '그녀의 어머니는 훌륭한 왕비야.'}]},
#   {'단어': 'neighbor',
#    '단어 뜻': ['이웃'],
#    '품사': '명사',
#    '예문': [{'영문': 'I’m your new neighbor.', '한글': '저는 새로 온 이웃입니다.'}]},
#   {'단어': 'master',
#    '단어 뜻': ['완전히 익히다'],
#    '품사': 'v.',
#    '예문': [{'영문': "It's not easy to master Chinese characters in a short time.",
#      '한글': '짧은 시간 안에 한자를 완전히 익히는 것은 쉽지 않다.'}]},
#   {'단어': 'member',
#    '단어 뜻': ['회원', '회원, 구성원'],
#    '품사': '',
#    '예문': [{'영문': 'We are finding new members for our team.',
#      '한글': '우리는 팀의 새로운 회원을 찾고 있어.'},
#     {'영문': 'Tommy is a member of a baseball club.',
#      '한글': 'Tommy는 야구 동아리 회원이야.'}]},
#   {'단어': 'pat',
#    '단어 뜻': ['쓰다듬다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m patting my pets.', '한글': '나는 애완동물을 쓰다듬고 있어.'}]}],
#  'category_7': [{'단어': 'woman',
#    '단어 뜻': ['여자'],
#    '품사': '명사',
#    '예문': [{'영문': 'The woman is my mom.', '한글': '그 여자분은 우리 엄마셔.'},
#     {'영문': 'The woman found my key.', '한글': '그 여자가 내 열쇠를 찾았다.'},
#     {'영문': 'The little girl become a beautiful woman.',
#      '한글': '그 작은 소녀는 아름다운 여자가 되었어.'}]},
#   {'단어': 'lady',
#    '단어 뜻': ['숙녀'],
#    '품사': '',
#    '예문': [{'영문': 'Jane is a beautiful lady', '한글': 'Jane은 아름다운 숙녀야.'},
#     {'영문': 'She is a good lady.', '한글': '그녀는 멋진 숙녀야.'}]},
#   {'단어': 'girl',
#    '단어 뜻': ['소녀'],
#    '품사': '명사',
#    '예문': [{'영문': 'The girl is my sister.', '한글': '그 소녀는 우리 누나야.'},
#     {'영문': 'Mary is a smart girl.', '한글': '메리는 영리한 소녀다.'}]},
#   {'단어': 'gentleman',
#    '단어 뜻': ['신사'],
#    '품사': '',
#    '예문': [{'영문': 'Mr. Watson is a kind gentleman.',
#      '한글': 'Watson씨는 친절한 신사야.'}]}],
#  'category_8': [{'단어': 'transportation',
#    '단어 뜻': ['수송, 교통 수단'],
#    '품사': 'n.',
#    '예문': [{'영문': 'I use public transportation to go to school.',
#      '한글': '나는 대중교통을 이용해서 학교에 간다.'}]},
#   {'단어': 'travel',
#    '단어 뜻': ['여행하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I want to travel abroad.', '한글': '나는 해외 여행을 하고 싶어.'},
#     {'영문': 'My father traveled to many countries.',
#      '한글': '우리 아버지는 많은 나라를 여행하셨어.'},
#     {'영문': 'I like to travel alone.', '한글': '나는 혼자 여행하는 것을 좋아해.'}]},
#   {'단어': 'trip',
#    '단어 뜻': ['걸려 넘어지다', '여행'],
#    '품사': '동사',
#    '예문': [{'영문': 'I tripped over the bag.', '한글': '나는 가방에 걸려 넘어졌어.'},
#     {'영문': 'Last summer I went on a trip to London.',
#      '한글': '지난 여름에 나는 런던으로 여행을 갔어.'},
#     {'영문': 'They go on a trip every weekend.', '한글': '그들은 주말마다 여행 을 가.'}]},
#   {'단어': 'navigate',
#    '단어 뜻': ['길을 찾다, 항해하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'We navigate with a navigation system.',
#      '한글': '우리는 네비게이션을 이용해 길을 찾아.'}]},
#   {'단어': 'train',
#    '단어 뜻': ['훈련시키다', '기차'],
#    '품사': '동사',
#    '예문': [{'영문': 'I train my team.', '한글': '나는 내 팀을 훈련시켜.'},
#     {'영문': 'That train is long.', '한글': '저 기차는 길어.'},
#     {'영문': 'The train is black.', '한글': '그 기차는 검은색이야.'}]},
#   {'단어': 'journey',
#    '단어 뜻': ['여행'],
#    '품사': '명사',
#    '예문': [{'영문': 'He is planning a six-week journey to Europe.',
#      '한글': '그는 유럽으로 6주 간의 여행을 계획하고 있어.'},
#     {'영문': 'I was tired from the long journey.', '한글': '나는 장거리 여행으로 피곤했어.'}]},
#   {'단어': 'traffic',
#    '단어 뜻': ['교통'],
#    '품사': '명사',
#    '예문': [{'영문': 'Traffic on the road was busy this morning.',
#      '한글': '오늘 아침 도로의 교통이 붐볐어.'}]}],
#  'category_9': [{'단어': 'amusement',
#    '단어 뜻': ['즐거움, 재미'],
#    '품사': 'n.',
#    '예문': [{'영문': 'She keeps a pet for amusement.',
#      '한글': '그녀는 즐거움을 위해 애완동물을 기른다.'}]},
#   {'단어': 'fun',
#    '단어 뜻': ['재미있는', '재미'],
#    '품사': '',
#    '예문': [{'영문': 'Riding a bike is fun.', '한글': '자전거 타는 것은 재미있다.'},
#     {'영문': 'We had fun at the beach.', '한글': '우리는 해변에서 재미있었어.'},
#     {'영문': 'Jamie is friendly and full of fun.', '한글': 'Jamie는 다정하고 재미있어.'},
#     {'영문': 'The movie is fun.', '한글': '그 영화는 재미있어.'}]},
#   {'단어': 'hobby',
#    '단어 뜻': ['취미'],
#    '품사': '명사',
#    '예문': [{'영문': 'Her favorite hobby is making dolls.',
#      '한글': '그녀가 가장 좋아하는 취미는 인형 만들기야.'},
#     {'영문': 'My hobby is drawing cartoons.', '한글': '내 취미는 만화 그리기야.'},
#     {'영문': 'What’s your hobby?', '한글': '네 취미는 무엇이니?'}]},
#   {'단어': 'entertain',
#    '단어 뜻': ['즐겁게 하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'They gave a free street concert to entertain people.',
#      '한글': '그들은 사람들을 즐겁게 하기 위해 무료 거리 공연을 했다.'}]}],
#  'category_10': [{'단어': 'competition',
#    '단어 뜻': ['경쟁'],
#    '품사': 'n.',
#    '예문': [{'영문': 'There is a lot of competition between clubs to attract students.',
#      '한글': '동아리들 사이에서 학생들을 유치하기 위한 경쟁이 치열하다.'}]},
#   {'단어': 'contest',
#    '단어 뜻': ['대회'],
#    '품사': '명사',
#    '예문': [{'영문': 'When is the food cooking contest?', '한글': '음식 경연 대회는 언제니?'},
#     {'영문': 'He entered the singing contest.', '한글': '그는 노래 대회에 참가했어.'},
#     {'영문': 'A fishing contest is interesting.', '한글': '낚시 대회는 흥미롭다.'},
#     {'영문': 'I won first prize in the English speech contest.',
#      '한글': '나는 영어 말하기 대회에서 일등 상을 받았어.'}]},
#   {'단어': 'compete with',
#    '단어 뜻': ['~과 경쟁하다'],
#    '품사': 'phr.',
#    '예문': [{'영문': 'I competed with Jamie for the prize',
#      '한글': '나는 그 상을 두고 Jamie와 경쟁했다.'}]},
#   {'단어': 'compare',
#    '단어 뜻': ['비교하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Don’t compare yourself with others.',
#      '한글': '너 자신을 남과 비교하지 마라.'}]},
#   {'단어': 'participate in',
#    '단어 뜻': ['~에 참가하다'],
#    '품사': 'phr.',
#    '예문': [{'영문': 'Did the little boys participate in this crime?',
#      '한글': '그 어린 소년들이 이 범죄에 가담했나요?'}]}],
#  'category_11': [{'단어': 'composition',
#    '단어 뜻': ['구성 요소, 구성'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The main composition of hair is keratin.',
#      '한글': '모발의 주 구성 요소는 케라틴이다.'}]},
#   {'단어': 'write',
#    '단어 뜻': ['쓰다'],
#    '품사': '',
#    '예문': [{'영문': 'Let’s write.', '한글': '쓰자'}]},
#   {'단어': 'compose',
#    '단어 뜻': ['작곡하다'],
#    '품사': 'v.',
#    '예문': [{'영문': "I'm going to compose a simple and catchy melody.",
#      '한글': '나는 간단하고 기억하기 쉬운 멜로디를 작곡할 것이다.'}]},
#   {'단어': 'writer',
#    '단어 뜻': ['작가'],
#    '품사': '명사',
#    '예문': [{'영문': 'Do you want to be a writer?', '한글': '너는 작가가 되고 싶니?'},
#     {'영문': 'The writer is reading a book.', '한글': '그 작가는 책을 읽고 있다.'}]},
#   {'단어': 'reporter',
#    '단어 뜻': ['기자'],
#    '품사': '',
#    '예문': [{'영문': 'Kate is a reporter.', '한글': 'Kate는 기자야.'},
#     {'영문': 'I’m a reporter.', '한글': '나는 기자예요.'},
#     {'영문': 'The reporter met a famous artist.', '한글': '그 기자는 유명한 화가를 만났다.'}]},
#   {'단어': 'journalist',
#    '단어 뜻': ['기자, 언론인'],
#    '품사': 'n.',
#    '예문': [{'영문': 'What I have to do as a journalist is to reveal the truth.',
#      '한글': '기자로서 내가 해야 할 것은 진실을 밝히는 것이다.'}]},
#   {'단어': 'novelist',
#    '단어 뜻': ['소설가'],
#    '품사': 'n.',
#    '예문': [{'영문': 'He is a teacher and novelist.', '한글': '그는 교사이자 소설가이다.'}]},
#   {'단어': 'information',
#    '단어 뜻': ['정보'],
#    '품사': 'n.',
#    '예문': [{'영문': 'TV gives us lots of information quickly.',
#      '한글': 'TV는 우리에게 많은 정보를 신속하게 전달한다.'}]},
#   {'단어': 'development',
#    '단어 뜻': ['발달, 개발'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Learning environment has an effect on growth and development of students.',
#      '한글': '학습 환경은 학생들의 성장과 발달에 영향을 끼친다.'}]},
#   {'단어': 'report',
#    '단어 뜻': ['발표하다', '보도하다, 알리다', '성적표'],
#    '품사': '동사',
#    '예문': [{'영문': 'The doctor reported that the patient recovered.',
#      '한글': '의사는 그 환자가 회복되었다고 발표했어.'},
#     {'영문': 'He is reporting the news.', '한글': '그는 뉴스를 보도하는 중이야.'},
#     {'영문': 'Where should I put this report card?',
#      '한글': '이 성적표를 어디에 두어야 할까?'}]},
#   {'단어': 'read',
#    '단어 뜻': ['읽다'],
#    '품사': '',
#    '예문': [{'영문': 'They read books.', '한글': '그들은 책을 읽어.'}]},
#   {'단어': 'word',
#    '단어 뜻': ['단어'],
#    '품사': '명사',
#    '예문': [{'영문': 'I can spell many English words.',
#      '한글': '나는 많은 영어 단어의 철자를 말할 수 있어.'},
#     {'영문': 'Write the word on the blackboard.', '한글': '칠판에 단어를 써 봐.'}]},
#   {'단어': 'think',
#    '단어 뜻': ['생각하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I think it’s a good idea.', '한글': '나는 그것이 좋은 생각이라고 생각해.'},
#     {'영문': 'I think he is hungry.', '한글': '나는 그가 배고프다고 생각해.'}]},
#   {'단어': 'imitate',
#    '단어 뜻': ['모방하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Nobody can imitate his dancing.',
#      '한글': '아무도 그의 춤을 모방할 수 없다.'}]},
#   {'단어': 'type',
#    '단어 뜻': ['종류'],
#    '품사': '명사',
#    '예문': [{'영문': 'This type of dog has short legs.',
#      '한글': '이 개 종류는 짧은 다리를 갖고 있어.'}]},
#   {'단어': 'spell',
#    '단어 뜻': ['철자를 쓰\n다', '철자를 쓰다'],
#    '품사': '동사',
#    '예문': [{'영문': 'How do you spell your name?', '한글': '네 이름의 철자를 어떻게 쓰니?'},
#     {'영문': 'How do you spell your name?', '한글': '네 이름은 철자를 어떻게 쓰니?'}]},
#   {'단어': 'career',
#    '단어 뜻': ['직장 생활, 직업'],
#    '품사': '명사',
#    '예문': [{'영문': 'My uncle started his career as a clerk.',
#      '한글': '우리 삼촌은 점원으로 직장 생활을 시작했어.'}]},
#   {'단어': 'postscript',
#    '단어 뜻': ['(편지의) 추신'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Please say hello to him in postscript.',
#      '한글': '추신으로 그에게 안부를 전해 주세요.'}]},
#   {'단어': 'preview',
#    '단어 뜻': ['시사회, 예고편'],
#    '품사': 'n.',
#    '예문': [{'영문': 'We saw a preview of the movie on the Internet.',
#      '한글': '우리는 그 영화의 예고편을 인터넷에서 봤다.'}]},
#   {'단어': 'outgoing',
#    '단어 뜻': ['외향적인'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'When I was an elementary school student, I was an outgoing child.',
#      '한글': '나는 초등학생이었을 때 외향적인 아이였다.'}]},
#   {'단어': 'poem',
#    '단어 뜻': ['시'],
#    '품사': '명사',
#    '예문': [{'영문': 'I like reading poems.', '한글': '나는 시 읽는 것을 좋아해.'}]},
#   {'단어': 'letter',
#    '단어 뜻': ['편지'],
#    '품사': '',
#    '예문': [{'영문': 'Whose letter is that?', '한글': '저것은 누구의 편지니?'}]},
#   {'단어': 'invent',
#    '단어 뜻': ['발명하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'He wants to invent something new.',
#      '한글': '그는 뭔가 새로운 것을 발명하고 싶어 해.'}]},
#   {'단어': 'subject',
#    '단어 뜻': ['주제', '과목'],
#    '품사': '명사',
#    '예문': [{'영문': 'What is the subject of this poem?', '한글': '이 시의 주제는 무엇이니?'},
#     {'영문': 'My favorite subject is math.', '한글': '내가 가장 좋아하는 과목은 수학이야.'}]},
#   {'단어': 'announcer',
#    '단어 뜻': ['아나운서'],
#    '품사': '명사',
#    '예문': [{'영문': 'My sister is an announcer for BBC television.',
#      '한글': '우리 언니는 BBC 텔레비전의 아나운서야.'}]},
#   {'단어': 'participant',
#    '단어 뜻': ['참가자'],
#    '품사': 'n.',
#    '예문': [{'영문': 'There were many participants in the race.',
#      '한글': '그 경주에는 참가자가 많았다.'}]},
#   {'단어': 'editor',
#    '단어 뜻': ['편집자'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The writer sent an email to the editor.',
#      '한글': '그 작가는 편집자에게 이메일을 보냈다.'}]},
#   {'단어': 'narrator',
#    '단어 뜻': ['내레이터'],
#    '품사': 'n.',
#    '예문': [{'영문': 'He is the narrator of documentaries about wild animals.',
#      '한글': '그는 야생'}]},
#   {'단어': 'criticize',
#    '단어 뜻': ['비판하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Adults must not criticize the child who is trying so hard.',
#      '한글': '어른은 매우 열심히 하는 아이를 비판하면 안 된다.'}]},
#   {'단어': 'model',
#    '단어 뜻': ['모형'],
#    '품사': '',
#    '예문': [{'영문': 'I’m making a model airplane.', '한글': '나는 모형 비행기를 만들고 있어.'}]},
#   {'단어': 'diary',
#    '단어 뜻': ['일기'],
#    '품사': '명사',
#    '예문': [{'영문': 'Do you write in your diary every day?',
#      '한글': '너는 매일 일기를 쓰니?'}]}],
#  'category_12': [{'단어': 'definition',
#    '단어 뜻': ['정의, 의미'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Some people have different opinions about the definition of a planet.',
#      '한글': '몇몇 사람들은 행성의 정의에 대해 다른 의견을 가지고 있다.'}]},
#   {'단어': 'dictionary',
#    '단어 뜻': ['사전'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Look up this word in the dictionary.',
#      '한글': '이 단어를 사전에서 찾아봐라.'}]},
#   {'단어': 'term',
#    '단어 뜻': ['학기, 기간'],
#    '품사': 'n.',
#    '예문': [{'영문': 'I have to study for the term exam.',
#      '한글': '나는 기말 시험을 위해 공부해야 한다.'}]}],
#  'category_13': [{'단어': 'decision',
#    '단어 뜻': ['결정, 판단'],
#    '품사': 'n.',
#    '예문': [{'영문': 'I will put my decision to exercise regularly in action soon.',
#      '한글': '나는 규칙적으로 운동을 하겠다는 결심을 곧 실천에 옮길 것이다.'}]},
#   {'단어': 'choose',
#    '단어 뜻': ['선택하다', '고르다'],
#    '품사': '',
#    '예문': [{'영문': 'Choose the best book for you.', '한글': '네게 가장 좋은 책을 골라.'},
#     {'영문': 'You can choose the color you want.', '한글': '네가 원하는 색을 골라도 돼.'}]},
#   {'단어': 'pick',
#    '단어 뜻': ['고르다, 꺾다', '집다'],
#    '품사': '동사',
#    '예문': [{'영문': 'She is about to pick the plant.',
#      '한글': '그녀는 식물을 꺾으려고 하고 있어.'},
#     {'영문': 'Pick up the book.', '한글': '그 책을 집어.'}]},
#   {'단어': 'select',
#    '단어 뜻': ['선택하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Please select only one person.', '한글': '단 한 사람만 선택하세요.'}]},
#   {'단어': 'decide',
#    '단어 뜻': ['결정하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’ll decide after I look at it.',
#      '한글': '나는 그것을 본 후에 결정할 거야.'}]},
#   {'단어': 'both A and B',
#    '단어 뜻': ['A와 B 둘 다'],
#    '품사': 'conj.',
#    '예문': [{'영문': 'We both watched a movie and had dinner.',
#      '한글': '우리는 영화도 보고 저녁도 먹었다.'}]},
#   {'단어': 'consider',
#    '단어 뜻': ['고려하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m considering buying a teddy bear.',
#      '한글': '나는 곰 인형을 살까 고민하고 있어.'}]},
#   {'단어': 'take',
#    '단어 뜻': ['가져가다'],
#    '품사': '',
#    '예문': [{'영문': 'Take this umbrella.', '한글': '이 우산을 가져가.'}]}],
#  'category_14': [{'단어': 'conclusion',
#    '단어 뜻': ['결론'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The jury reached the conclusion that he was guilty.',
#      '한글': '배심원단은 그가 유죄라는 결론을 내렸다.'}]},
#   {'단어': 'summary',
#    '단어 뜻': ['요약, 개요'],
#    '품사': 'n.',
#    '예문': [{'영문': "Let's write a summary of this paragraph.",
#      '한글': '이 단락의 요약문을 써 봅시다.'}]},
#   {'단어': 'summarize',
#    '단어 뜻': ['요약하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Students should summarize this article by next week.',
#      '한글': '학생들은 다음 주까지 이 기사를 요약해야 한다.'}]},
#   {'단어': 'review',
#    '단어 뜻': ['복습하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I reviewed the book before the test.',
#      '한글': '나는 시험 전에 책을 복습했어.'}]},
#   {'단어': 'end',
#    '단어 뜻': ['끝나다'],
#    '품사': '',
#    '예문': [{'영문': 'The movie ends at 3 o’clock.', '한글': '그 영화는 3시에 끝나.'},
#     {'영문': 'The game ends at five.', '한글': '그 시합은 다섯 시에 끝난다.'},
#     {'영문': 'The boring movie ended finally.', '한글': '그 지겨운 영화가 마침내 끝났어.'}]}],
#  'category_15': [{'단어': 'division',
#    '단어 뜻': ['분할, 분배'],
#    '품사': 'n.',
#    '예문': [{'영문': 'We observed cell division through a microscope.',
#      '한글': '우리는 현미경을 통해 세포 분열을 관찰했다.'}]},
#   {'단어': 'divide',
#    '단어 뜻': ['나누다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Divide this pizza into eight pieces.',
#      '한글': '이 피자를 여덟 조각으로 나눠.'}]}],
#  'category_16': [{'단어': 'expansion',
#    '단어 뜻': ['확대, 팽창'],
#    '품사': 'n.',
#    '예문': [{'영문': 'We learned the expansion and contraction of the metal in the science class',
#      '한글': '우리는 과학 시간에 금속의 팽창과 수축에 대해 배웠다.'}]},
#   {'단어': 'expand',
#    '단어 뜻': ['확대하다, 팽창하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Metals expand when they are heated.',
#      '한글': '금속은 열을 받으면 팽창한다.'}]},
#   {'단어': 'extend',
#    '단어 뜻': ['더 길게 만들다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'The government has a plan to extend the bike path on the island.',
#      '한글': '정부는 그 섬의 자전거 도로를 확장하려는 계획을 갖고 있다.'}]},
#   {'단어': 'displace',
#    '단어 뜻': ['대체하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Computers displaced typewriters.',
#      '한글': '컴퓨터가 타자기를 대체했어.'}]},
#   {'단어': 'stretch',
#    '단어 뜻': ['늘이다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Stretch your body', '한글': '몸을 쭉 늘여.'}]}],
#  'category_17': [{'단어': 'repair',
#    '단어 뜻': ['수리하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'He repairs computers.', '한글': '그는 컴퓨터를 수리해.'},
#     {'영문': 'My car is being repaired.', '한글': '내 차는 수리 중에 있어.'}]},
#   {'단어': 'fix',
#    '단어 뜻': ['고치다'],
#    '품사': '',
#    '예문': [{'영문': 'My dad is fixing the water pipe.',
#      '한글': '우리 아빠는 수도관을 고치고 계셔.'}]},
#   {'단어': 'recover',
#    '단어 뜻': ['회복하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'I hope my grandmother will recover her senses soon.',
#      '한글': '나는 우리 할머니께서 곧 의식을 회복하시길 바란다.'}]},
#   {'단어': 'help',
#    '단어 뜻': ['도와주다'],
#    '품사': '',
#    '예문': [{'영문': 'I can’t help you.', '한글': '나는 너를 도울 수 없어.'}]}],
#  'category_18': [{'단어': 'result',
#    '단어 뜻': ['결과'],
#    '품사': '명사',
#    '예문': [{'영문': 'You will get your exam results next week.',
#      '한글': '여러분은 다음 주에 시험 결과를 받을 거에요.'}]},
#   {'단어': 'outcome',
#    '단어 뜻': ['결과'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The outcome of the baseball game is hard to foretell.',
#      '한글': '야구 경기의 결과는 예측하기 어렵다.'}]},
#   {'단어': 'output',
#    '단어 뜻': ['생산량'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The daily output of fans is getting smaller in winter.',
#      '한글': '선풍기의 하루 생산량은 겨울에 더 줄어들고 있다.'}]}],
#  'category_19': [{'단어': 'bake',
#    '단어 뜻': ['굽다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m baking some bread.', '한글': '나는 빵을 굽고 있어.'}]},
#   {'단어': 'cook',
#    '단어 뜻': ['요리하다', '요리사'],
#    '품사': '',
#    '예문': [{'영문': 'Who is cooking dinner?', '한글': '누가 저녁을 요리하고 있니?'},
#     {'영문': 'The cook taught the cooking class.', '한글': '그 요리사는 요리 반을 지도했어.'},
#     {'영문': 'I’m a cook.', '한글': '나는 요리사야.'},
#     {'영문': 'She is cooking.', '한글': '그녀는 요리하고 있어.'},
#     {'영문': 'We are cooking dinner.', '한글': '우리는 저녁 식사를 요리하고 있어.'}]},
#   {'단어': 'boil',
#    '단어 뜻': ['끓다', '삶다, 끓이다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Boil the water.', '한글': '물을 끓여.'},
#     {'영문': 'Boil the eggs for seven minutes.', '한글': '달걀을 7분간 삶으세요.'}]},
#   {'단어': 'pan',
#    '단어 뜻': ['팬, 냄비'],
#    '품사': 'n.',
#    '예문': [{'영문': 'A chef put the butter and oil in a large pan.',
#      '한글': '요리사는 커다란 팬에 버터와 기름을 넣었다.'}]},
#   {'단어': 'recipe',
#    '단어 뜻': ['요리법'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Tell me the recipe for the chocolate cookies.',
#      '한글': '초콜릿 쿠키 요리법을 나에게 말해 줘.'}]},
#   {'단어': 'stir',
#    '단어 뜻': ['젓다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Stir two eggs quickly with a long fork.',
#      '한글': '긴 포크로 달걀 두 개를 빠르게 저어라.'}]}],
#  'category_20': [{'단어': 'leave',
#    '단어 뜻': ['떠나다', '남가다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m leaving now.', '한글': '나는 지금 떠나.'},
#     {'영문': 'I must leave a flower for him.', '한글': '나는 그를 위해 꽃 한 송이를 남겨야 해.'},
#     {'영문': 'We will leave at 10 o’clock.', '한글': '우리는 10시 정각에 떠날 거야.'},
#     {'영문': 'If you leave right now, you won’t be late.',
#      '한글': '지금 당장 떠나면 늦지 않을 거야.'}]},
#   {'단어': 'stay',
#    '단어 뜻': ['머무르다', '지내다, 머무르다'],
#    '품사': '동사',
#    '예문': [{'영문': 'We stayed home last night and watched TV.',
#      '한글': '우리는 어젯밤에 집에 머무르면서 텔레비전을 봤어.'},
#     {'영문': 'You should stay at home today.', '한글': '너는 오늘 집에 있어야 해.'},
#     {'영문': 'We stay there every summer.', '한글': '우리는 여름마다 그곳에 머물러.'},
#     {'영문': 'He stayed at the hotel for two days.',
#      '한글': '그는 이틀 동안 그 호텔에서 머물렀다.'}]},
#   {'단어': 'depart',
#    '단어 뜻': ['출발하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'The next train will depart 10 minutes later.',
#      '한글': '다음 열차는 10분 후 출발할 것이다.'}]},
#   {'단어': 'exit',
#    '단어 뜻': ['출구'],
#    '품사': '명사',
#    '예문': [{'영문': 'Use the emergency exit in case of fire.',
#      '한글': '화재 시에는 비상 출구를 이용하세요.'}]},
#   {'단어': 'be going to',
#    '단어 뜻': ['~ 할 것이다'],
#    '품사': '',
#    '예문': [{'영문': 'I am going to play soccer.', '한글': '나는 축구를 할 거야.'}]},
#   {'단어': 'return',
#    '단어 뜻': ['돌아오다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m leaving but will return at 6 p.m.',
#      '한글': '나는 떠나지만 오후 6시에 돌아올 거야.'},
#     {'영문': 'Why does a boomerang return to its thrower?',
#      '한글': '왜 부메랑은 던진 사람에게 되돌아오는 걸까?'}]},
#   {'단어': 'flee',
#    '단어 뜻': ['도망치다'],
#    '품사': '동사',
#    '예문': [{'영문': 'She is fleeing from the prison.',
#      '한글': '그녀는 감옥에서 도망치는 중이야.'}]},
#   {'단어': 'come',
#    '단어 뜻': ['오다'],
#    '품사': '',
#    '예문': [{'영문': 'Can you come here?', '한글': '여기로 올 수 있니?'},
#     {'영문': 'Come here, please.', '한글': '여기로 오세요.'}]},
#   {'단어': 'disconnect',
#    '단어 뜻': ['연결을 끊다'],
#    '품사': 'v.',
#    '예문': [{'영문': "I'd like to have my phone disconnected as of September 22.",
#      '한글': '나는 9월 22일 자로 전화가 해지되기를 원한다.'}]},
#   {'단어': 'come home',
#    '단어 뜻': ['집에 오다'],
#    '품사': '',
#    '예문': [{'영문': 'I come home at 6 p.m.', '한글': '나는 오후 6시에 잠에 와.'}]},
#   {'단어': 'disappear',
#    '단어 뜻': ['사라지다'],
#    '품사': '동사',
#    '예문': [{'영문': 'The dinosaurs disappeared millions of years ago.',
#      '한글': '공룡들은 수백만 년 전에 사라졌어.'}]},
#   {'단어': 'away',
#    '단어 뜻': ['멀리'],
#    '품사': '',
#    '예문': [{'영문': 'The boat is going away.', '한글': '그 보트는 멀리 가고 있어.'}]},
#   {'단어': 'go',
#    '단어 뜻': ['가다'],
#    '품사': '',
#    '예문': [{'영문': 'Go there, please.', '한글': '거기로 가 주세요.'}]},
#   {'단어': 'get to',
#    '단어 뜻': ['~에 이르다, 닿다'],
#    '품사': 'phr.',
#    '예문': [{'영문': 'Can you tell me how to get to the post office?',
#      '한글': '우체국에 가는 길 좀 가르쳐 주시겠습니까?'}]},
#   {'단어': 'bye',
#    '단어 뜻': ['잘 가'],
#    '품사': '',
#    '예문': [{'영문': 'Bye, Mike.', '한글': '잘 가, Mike야.'}]},
#   {'단어': 'hide',
#    '단어 뜻': ['숨다, 숨기다'],
#    '품사': '',
#    '예문': [{'영문': 'My cat hides under the bed.', '한글': '우리 고양이는 침대 밑에 숨어.'}]}],
#  'category_21': [{'단어': 'above',
#    '단어 뜻': ['~보다 위에'],
#    '품사': 'prep.',
#    '예문': [{'영문': 'Our plane was flying above the clouds.',
#      '한글': '우리 비행기는 구름 위를 날고 있었다.'}]},
#   {'단어': 'below',
#    '단어 뜻': ['~보다 아래에'],
#    '품사': 'prep.',
#    '예문': [{'영문': 'The sun sank below the horizon.', '한글': '태양이 지평선 아래로 졌다.'}]},
#   {'단어': 'over',
#    '단어 뜻': ['~을 넘어서'],
#    '품사': '',
#    '예문': [{'영문': 'Mark jumps over the wall.', '한글': 'Mark는 벽을 뛰어 넘어.'}]},
#   {'단어': 'under',
#    '단어 뜻': ['~아래에', '~ 아래에'],
#    '품사': '',
#    '예문': [{'영문': 'There is a ball under the bed.', '한글': '침대 아래에 공 하나가 있어.'},
#     {'영문': 'It’s under the desk.', '한글': '그것은 책상 아래에 있어.'}]}],
#  'category_22': [{'단어': 'because of',
#    '단어 뜻': ['~ 때문에'],
#    '품사': 'prep.',
#    '예문': [{'영문': 'I couldn’t sleep last night because of you.',
#      '한글': '나는 너 때문에 지난밤 잠을 잘 수 없었다.'}]},
#   {'단어': 'why',
#    '단어 뜻': ['왜'],
#    '품사': '',
#    '예문': [{'영문': 'Why does your hair turn gray?', '한글': '왜 우리 머리카락은 히끗히끗해질까?'},
#     {'영문': 'Why are you so happy?', '한글': '너는 왜 그렇게 행복하니?'}]},
#   {'단어': 'because',
#    '단어 뜻': ['~하기 때문\n에'],
#    '품사': '접속사',
#    '예문': [{'영문': 'Tim is angry because Amy made a mistake in the report.',
#      '한글': 'Amy가 보고서에서 실수를 했기 때문에 Tim이 화났어.'}]},
#   {'단어': 'curious',
#    '단어 뜻': ['궁금한'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'I’m curious about who the painter is.',
#      '한글': '나는 화가가 누구인지 궁금하다.'},
#     {'영문': 'Are you curious about space?', '한글': '너는 우주에 대해 궁금하니?'}]},
#   {'단어': 'principle',
#    '단어 뜻': ['원칙'],
#    '품사': 'n.',
#    '예문': [{'영문': 'It is my principle not to be late for school.',
#      '한글': '학교에 늦지 않는다는 것이 나의 원칙이다.'}]},
#   {'단어': 'explain',
#    '단어 뜻': ['설명하다'],
#    '품사': '',
#    '예문': [{'영문': 'I’ll explain the rules of this game.',
#      '한글': '내가 이 게임의 규칙을 설명해 줄게.'},
#     {'영문': 'Let me explain why the answer is b.', '한글': '왜 답이 b인지 설명할게요.'}]},
#   {'단어': 'understand',
#    '단어 뜻': ['이해하다'],
#    '품사': '',
#    '예문': [{'영문': 'He can understand it.', '한글': '그는 그것을 이해할 수 있어.'},
#     {'영문': 'I understand how you feel.', '한글': '네 기분 이해해.'}]},
#   {'단어': 'illogical',
#    '단어 뜻': ['비논리적인'],
#    '품사': 'adj.',
#    '예문': [{'영문': "People don't believe his illogical argument.",
#      '한글': '사람들은 그의 비논리적인 주장을 믿지 않는다.'}]}],
#  'category_23': [{'단어': 'once',
#    '단어 뜻': ['일단 ~하면', '한 번'],
#    '품사': 'conj.',
#    '예문': [{'영문': "Once I start to read comic books, I can't stop.",
#      '한글': '일단 내가 만화 책을 읽기 시작하면, 멈출 수가 없다.'},
#     {'영문': 'I’ve seen this movie once.', '한글': '나는 이 영화를 한 번 본 적이 있어.'},
#     {'영문': 'My family goes camping once a month.',
#      '한글': '우리 가족은 한 달에 한 번 캠핑하러 간다.'},
#     {'영문': 'I will say this only once, so listen carefully.',
#      '한글': '나는 이것을 한 번만 말할 거니까 주의해서 들어.'},
#     {'영문': 'I take piano lessons once a week.',
#      '한글': '나는 일주일에 한 번 피아노 수업을 들어.'}]},
#   {'단어': 'twice',
#    '단어 뜻': ['두 번'],
#    '품사': '부사',
#    '예문': [{'영문': 'We go to the movies once or twice a month.',
#      '한글': '우리는 한 달에 한 번 또는 두 번 영화를 보러 가.'},
#     {'영문': 'I clean my room twice a week.', '한글': '나는 일주일에 두 번 내 방을 청소해.'}]},
#   {'단어': 'again',
#    '단어 뜻': ['또', '다시'],
#    '품사': '',
#    '예문': [{'영문': 'Try again.', '한글': '또 시도해 봐.'},
#     {'영문': 'See you again soon.', '한글': '곧 다시 봐.'}]}],
#  'category_24': [{'단어': 'unless',
#    '단어 뜻': ['~하지 않는다면'],
#    '품사': 'conj.',
#    '예문': [{'영문': 'You’ll miss the bus unless you walk more quickly.',
#      '한글': '좀 더 빨리 걷지 않는다면, 너는 버스를 놓치게 될 것이다.'}]},
#   {'단어': 'until',
#    '단어 뜻': ['~할 때까지', '~때까지'],
#    '품사': 'conj.',
#    '예문': [{'영문': "Let's take a rest in the house until the rain stops.",
#      '한글': '비가 그칠 때까지 집에서 쉬자.'},
#     {'영문': 'I have to study until five.', '한글': '난 다섯시까지 공부해야 해.'}]},
#   {'단어': 'although',
#    '단어 뜻': ['비록 ~이긴 하지만'],
#    '품사': 'conj.',
#    '예문': [{'영문': 'Although I was sick, I went to school yesterday.',
#      '한글': '비록 나는 아팠지만 어제 학교에 갔다.'}]},
#   {'단어': 'or',
#    '단어 뜻': ['또는'],
#    '품사': '',
#    '예문': [{'영문': 'Which do you like, apples or bananas?',
#      '한글': '너는 사과 또는 바나나 중에 어느 것을 좋아하니?'}]},
#   {'단어': 'otherwise',
#    '단어 뜻': ['그렇지 않으면'],
#    '품사': 'adv.',
#    '예문': [{'영문': 'Leave right now, otherwise you will be late.',
#      '한글': '지금 출발해라, 그렇지 않으면 너는 늦을 것이다.'}]},
#   {'단어': 'except',
#    '단어 뜻': ['제외하고는'],
#    '품사': '전치사',
#    '예문': [{'영문': 'The store is open every day except Sunday.',
#      '한글': '그 가게는 일요일을 제외하고 매일 문을 열어.'}]}],
#  'category_25': [{'단어': 'when',
#    '단어 뜻': ['~할 때', '언제'],
#    '품사': 'conj.',
#    '예문': [{'영문': 'I feel happy when I see snow', '한글': '나는 눈을 볼 때 행복하다.'},
#     {'영문': 'When is your birthday?', '한글': '네 생일은 언제니?'}]},
#   {'단어': 'soon',
#    '단어 뜻': ['곧, 머지않아', '곧'],
#    '품사': '',
#    '예문': [{'영문': 'The bus will come soon.', '한글': '버스가 곧 올 것이다.'},
#     {'영문': 'See you soon!', '한글': '곧 또 보자!'}]},
#   {'단어': 'never',
#    '단어 뜻': ['결코~않는'],
#    '품사': '부사',
#    '예문': [{'영문': 'We will never forget it.', '한글': '우리는 결코 그것을 잊지 않을 거야.'}]},
#   {'단어': 'already',
#    '단어 뜻': ['이미'],
#    '품사': '부사',
#    '예문': [{'영문': 'We’ve already had lunch.', '한글': '우리는 이미 점심을 먹었어.'},
#     {'영문': 'I already have a pen.', '한글': '나는 이미 펜을 가지고 있어.'}]}],
#  'category_26': [{'단어': 'brush',
#    '단어 뜻': ['빗다', '빗'],
#    '품사': '동사',
#    '예문': [{'영문': 'You must brush your hair every day.',
#      '한글': '너는 매일 머리를 빗어야 해.'},
#     {'영문': 'This is her brush.', '한글': '이것은 그녀의 빗이야.'}]},
#   {'단어': 'toothbrush',
#    '단어 뜻': ['칫솔'],
#    '품사': '명사',
#    '예문': [{'영문': 'There is a toothbrush in the bathroom.',
#      '한글': '욕실에는 칫솔이 있어.'}]},
#   {'단어': 'toothpaste',
#    '단어 뜻': ['치약'],
#    '품사': '명사',
#    '예문': [{'영문': 'There is toothpaste in the bathroom.',
#      '한글': '욕실에는 치약이 있어.'}]},
#   {'단어': 'soap',
#    '단어 뜻': ['비누'],
#    '품사': '명사',
#    '예문': [{'영문': 'There is soap in the bathroom.', '한글': '욕실에는 비누가 있어.'}]}],
#  'category_27': [{'단어': 'phone',
#    '단어 뜻': ['전화'],
#    '품사': '명사',
#    '예문': [{'영문': 'Can you get the phone for me?', '한글': '전화 좀 대신 받아 주실래요?'}]},
#   {'단어': 'telephone',
#    '단어 뜻': ['전화'],
#    '품사': '',
#    '예문': [{'영문': 'The telephone is white.', '한글': '그 전화기는 흰색이야.'}]},
#   {'단어': 'call',
#    '단어 뜻': ['부르다, 전\n화하다', '전화하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m calling my doctor.', '한글': '나는 의사를 부를 거야.'},
#     {'영문': 'I’ll call you again.', '한글': '내가 다시 전화할게.'}]},
#   {'단어': 'Phone number',
#    '단어 뜻': ['전화번호'],
#    '품사': '',
#    '예문': [{'영문': 'What’s your phone number?', '한글': '네 전호번호는 무엇이니?'}]}],
#  'category_28': [{'단어': 'quiet',
#    '단어 뜻': ['조용한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'You must be quiet in the library.',
#      '한글': '너는 도서관에서는 조용히 해야 해.'},
#     {'영문': 'He plays the song and the whole class becomes quiet.',
#      '한글': '그가 노래를 틀면 학급 전체는 조용해진다.'},
#     {'영문': 'Be quiet.', '한글': '조용히 해.'},
#     {'영문': 'Your voice is too loud, please be quiet.',
#      '한글': '네 목소리는 너무 커, 조용히 해 줘.'},
#     {'영문': 'They are quiet.', '한글': '그들은 조용해.'}]},
#   {'단어': 'loud',
#    '단어 뜻': ['시끄러운'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Her voice was too loud.', '한글': '그녀의 목소리는 너무 시끄러웠어.'}]},
#   {'단어': 'noise',
#    '단어 뜻': ['소음'],
#    '품사': '명사',
#    '예문': [{'영문': 'Modern music is just noise to me.',
#      '한글': '현대 음악은 내게는 단지 소음이야.'},
#     {'영문': 'Don’t make noise in the library.', '한글': '도서관에서 시끄럽게 하지 마세요.'}]},
#   {'단어': 'silent',
#    '단어 뜻': ['조용한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The cat’s steps were silent.',
#      '한글': '그 고양이의 발자국 소리는 조용했어.'}]},
#   {'단어': 'noisy',
#    '단어 뜻': ['시끄러운'],
#    '품사': '',
#    '예문': [{'영문': 'They are noisy.', '한글': '그들은 시끄러워.'}]},
#   {'단어': 'sound',
# ...
#    '예문': [{'영문': 'Mr. Watson is a mail carrier.', '한글': 'Watson씨는 우편 배달부셔.'}]},
#   {'단어': 'stamp',
#    '단어 뜻': ['구르다'],
#    '품사': '동사',
#    '예문': [{'영문': 'The boy is stamping his foot.', '한글': '소년이 발을 구르고 있어.'}]},
#   {'단어': 'address',
#    '단어 뜻': ['주소'],
#    '품사': '명사',
#    '예문': [{'영문': 'This is my home address.', '한글': '이것은 우리 집 주소야.'}]}],
#  'category_210': [{'단어': 'helpful',
#    '단어 뜻': ['도움이 되는'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Listening to music while studying is not very helpful.',
#      '한글': '공부할 때 음악을 듣는 것은 별로 도움이 되지 않는다.'}]},
#   {'단어': 'useless',
#    '단어 뜻': ['쓸모 없는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The tent is useless in rainy weather.',
#      '한글': '그 텐트는 비가 오는 날씨에는 쓸모가 없어.'}]},
#   {'단어': 'useful',
#    '단어 뜻': ['유용한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Smart phones are very useful.', '한글': '스마트폰은 매우 유용해.'}]},
#   {'단어': 'important',
#    '단어 뜻': ['중요한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Friends are very important in our lives.',
#      '한글': '친구는 우리 삶에서 매우 중요해.'}]},
#   {'단어': 'use',
#    '단어 뜻': ['사용하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'You may use my pen.', '한글': '제 펜을 쓰셔도 됩니다.'},
#     {'영문': 'May I use your pencil?', '한글': '네 연필을 사용해도 될까?'},
#     {'영문': 'Why don’t you use a cold towel?',
#      '한글': '차가운 수건을 사용해 보는 것이 어떠니?'}]},
#   {'단어': 'benefit',
#    '단어 뜻': ['이점, 이익'],
#    '품사': 'n.',
#    '예문': [{'영문': 'You can feel the benefit of being unplugged about a month later.',
#      '한글': '당신은 약 한 달 후에 플러그를 뽑는 것의 이점을 느끼게 될 것이다.'}]},
#   {'단어': 'misuse',
#    '단어 뜻': ['남용'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Misuse of medicine can cause very dangerous problems.',
#      '한글': '약의 남용은 아주 위험한 문제를 초래할 수 있다.'}]}],
#  'category_211': [{'단어': 'hopeful',
#    '단어 뜻': ['희망에 찬, 기대하는'],
#    '품사': 'adj.',
#    '예문': [{'영문': "I'm hopeful that my grandfather will overcome his sickness soon.",
#      '한글': '나는 우리 할아버지께서 곧 병을 이겨내시길 희망한다.'}]},
#   {'단어': 'hope',
#    '단어 뜻': ['희망하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I hope so.', '한글': '나는 그러기를 희망해.'}]},
#   {'단어': 'believe',
#    '단어 뜻': ['믿다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I believe in angles because I have friends like you.',
#      '한글': '너희 같은 친구들이 있어서 나는 천사를 믿어.'},
#     {'영문': "I can't believe the news.", '한글': '나는 그 소식을 믿을 수 없다.'}]}],
#  'category_212': [{'단어': 'endless',
#    '단어 뜻': ['무한한, 한없는'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Children have endless possibilities for development.',
#      '한글': '아이들은 무한한 발전 가능성이 있다.'}]},
#   {'단어': 'nonstop',
#    '단어 뜻': ['직행의'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'When do you have nonstop buses?', '한글': '직행 버스는 언제 있습니까?'}]},
#   {'단어': 'beyond',
#    '단어 뜻': ['~ 저편에, ~너머'],
#    '품사': 'prep.',
#    '예문': [{'영문': 'There is a camp site beyond the hill.',
#      '한글': '언덕 너머 야영지가 있다.'}]},
#   {'단어': 'immortal',
#    '단어 뜻': ['죽지 않는, 불후의'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Hamlet is an immortal work', '한글': '햄릿은 불후의 명작이다.'}]}],
#  'category_213': [{'단어': 'librarian',
#    '단어 뜻': ['사서'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The librarian is putting new books on the bookshelves.',
#      '한글': '사서는 책꽂이에 새 책들을 꽂고 있다.'}]},
#   {'단어': 'secretary',
#    '단어 뜻': ['비서'],
#    '품사': 'n.',
#    '예문': [{'영문': 'If you have more questions, ask my secretary.',
#      '한글': '더 궁금한 사항이 있으면, 제 비서에게 문의하세요.'}]},
#   {'단어': 'library',
#    '단어 뜻': ['도서관'],
#    '품사': '',
#    '예문': [{'영문': 'I’m in the library.', '한글': '나는 도서관에 있어.'},
#     {'영문': 'I like to study in the library.', '한글': '난 도서관에서 공부하는 게 좋아.'}]},
#   {'단어': 'clerk',
#    '단어 뜻': ['점원'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The clerk helped me to choose the color of a cap.',
#      '한글': '점원이 내가 모자의 색을 고르는 것을 도와주었다.'}]},
#   {'단어': 'bill',
#    '단어 뜻': ['청구서'],
#    '품사': '명사',
#    '예문': [{'영문': 'I should pay these bills this month.',
#      '한글': '나는 이번 달에 이 청구서들을 납부해야 해.'}]},
#   {'단어': 'office',
#    '단어 뜻': ['사무실'],
#    '품사': '',
#    '예문': [{'영문': 'The office is small.', '한글': '그 사무실은 작아.'}]},
#   {'단어': 'consultant',
#    '단어 뜻': ['상담가'],
#    '품사': 'n.',
#    '예문': [{'영문': 'He is an experienced medical consultant.',
#      '한글': '그는 숙련된 의료 상담가이다.'}]},
#   {'단어': 'ruler',
#    '단어 뜻': ['자'],
#    '품사': '',
#    '예문': [{'영문': 'That is Susan’s ruler.', '한글': '저것은 Susan의 자야.'}]}],
#  'category_214': [{'단어': 'sun',
#    '단어 뜻': ['태양'],
#    '품사': '',
#    '예문': [{'영문': 'Look at the sun.', '한글': '태양을 봐.'}]},
#   {'단어': 'sunny',
#    '단어 뜻': ['화창한'],
#    '품사': '',
#    '예문': [{'영문': 'It’s sunny.', '한글': '화창해.'}]},
#   {'단어': 'sunshine',
#    '단어 뜻': ['햇빛'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Time, water, and some sunshine make the vegetables grow.',
#      '한글': '시간, 물, 그리고 햇빛은 채소를 자라게 한다.'}]},
#   {'단어': 'shine',
#    '단어 뜻': ['빛나다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Make hay while the sun shines.', '한글': '해가 비칠 때 건초를 말려.'}]},
#   {'단어': 'light',
#    '단어 뜻': ['가벼운', '전등'],
#    '품사': '',
#    '예문': [{'영문': 'It’s light.', '한글': '그것은 가벼워.'},
#     {'영문': 'There is a light on the wall.', '한글': '벽에 전등이 있어.'}]}],
#  'category_215': [{'단어': 'bad',
#    '단어 뜻': ['나쁜'],
#    '품사': '',
#    '예문': [{'영문': 'I’m bad.', '한글': '나는 기분이 나빠.'},
#     {'영문': 'He is bad.', '한글': '그는 나빠.'}]},
#   {'단어': 'terrible',
#    '단어 뜻': ['끔찍한', '심한, 지독한'],
#    '품사': '형용사',
#    '예문': [{'영문': 'What a terrible thing!', '한글': '정말 끔찍한 일이야!'},
#     {'영문': 'The terror was terrible.', '한글': '그 테러는 끔찍했어.'},
#     {'영문': 'This hamburger is terrible.', '한글': '이 햄버거는 맛이 형편없어.'}]}],
#  'category_216': [{'단어': 'runny',
#    '단어 뜻': ['콧물이 흐르는'],
#    '품사': '형용사',
#    '예문': [{'영문': 'I have a runny nose and a cough.', '한글': '콧물이 나고 기침도 나요.'}]},
#   {'단어': 'runny nose',
#    '단어 뜻': ['콧물'],
#    '품사': '',
#    '예문': [{'영문': 'The boy has a runny nose.', '한글': '그 소년은 콧물이 흘러.'}]}],
#  'category_217': [{'단어': 'amount',
#    '단어 뜻': ['액수'],
#    '품사': '명사',
#    '예문': [{'영문': 'The total amount came to a million won.',
#      '한글': '총액이 백만 원에 달했어.'}]},
#   {'단어': 'quantity',
#    '단어 뜻': ['양'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The price depends on the quantity of goods.',
#      '한글': '가격은 상품의 양에 따라 다르다.'}]},
#   {'단어': 'count',
#    '단어 뜻': ['세다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m counting numbers.', '한글': '숫자를 세고 있어.'},
#     {'영문': 'She counted the beds.', '한글': '그녀는 침대 개수를 세었다.'},
#     {'영문': 'Count how many eggs there are.', '한글': '달걀이 몇 개 있는지 세어 보세요.'}]},
#   {'단어': 'measure',
#    '단어 뜻': ['측정하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'We measured the weight of the pumpkin.',
#      '한글': '우리는 호박의 무게를 쟀다.'}]},
#   {'단어': 'population',
#    '단어 뜻': ['인구'],
#    '품사': '명사',
#    '예문': [{'영문': 'The world’s population is more than 7 billion.',
#      '한글': '세계의 인구는 70억이 넘어.'}]},
#   {'단어': 'quality',
#    '단어 뜻': ['질'],
#    '품사': 'n.',
#    '예문': [{'영문': 'There are products of high quality in the store.',
#      '한글': '그 가게에는 고품질의 제품들이 있다.'}]}],
#  'category_218': [{'단어': 'decrease',
#    '단어 뜻': ['줄이다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Decrease baking time to 20 minutes.',
#      '한글': '굽는 시간을 20분 줄이세요.'}]},
#   {'단어': 'reduce',
#    '단어 뜻': ['줄이다'],
#    '품사': 'v.',
#    '예문': [{'영문': "Let's reduce food and plastic waste to make the Earth healthy.",
#      '한글': '지구를 건강하게 만들기 위해 음식과 플라스틱 쓰레기를 줄이자.'}]},
#   {'단어': 'transform',
#    '단어 뜻': ['변형시키다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'The fish are genetically transformed because of the polluted water.',
#      '한글': '물고기들이 오염된 물 때문에 유전적으로 변형되었다.'}]}],
#  'category_219': [{'단어': 'house',
#    '단어 뜻': ['집'],
#    '품사': '',
#    '예문': [{'영문': 'The house is big.', '한글': '그 집은 커.'}]},
#   {'단어': 'kitchen',
#    '단어 뜻': ['부엌'],
#    '품사': '',
#    '예문': [{'영문': 'Mom is in the kitchen.', '한글': '엄마는 부엌에 계셔.'}]},
#   {'단어': 'household',
#    '단어 뜻': ['가정의'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'The company produces household goods.',
#      '한글': '그 회사는 가정용품을 생산한다.'}]},
#   {'단어': 'stove',
#    '단어 뜻': ['가스레인\n지', '가스레인지'],
#    '품사': '명사',
#    '예문': [{'영문': 'There is a stove in the kitchen.', '한글': '부엌에는 가스레인지가 있어.'},
#     {'영문': 'The stove is big.', '한글': '그 가스레인지는 커.'}]},
#   {'단어': 'home',
#    '단어 뜻': ['집'],
#    '품사': '',
#    '예문': [{'영문': 'I’m at home.', '한글': '나는 집에 있어.'}]},
#   {'단어': 'housewarming',
#    '단어 뜻': ['집들이'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Our housewarming party is on May 5.',
#      '한글': '우리 집들이는 5월 5일이다.'}]}],
#  'category_220': [{'단어': 'stairs',
#    '단어 뜻': ['계단'],
#    '품사': '',
#    '예문': [{'영문': 'The stairs are old.', '한글': '그 계단은 오래된 것이야.'}]},
#   {'단어': 'stair',
#    '단어 뜻': ['계단'],
#    '품사': '명사',
#    '예문': [{'영문': 'Don’t jump on the stairs.', '한글': '계단에서 뛰지 마세요.'}]},
#   {'단어': 'climb',
#    '단어 뜻': ['오르다'],
#    '품사': '동사',
#    '예문': [{'영문': 'He climbed up the ladder.', '한글': '그는 사다리를 타고 올라갔어.'}]}],
#  'category_221': [{'단어': 'fat',
#    '단어 뜻': ['뚱뚱한', '지방'],
#    '품사': '형용사',
#    '예문': [{'영문': 'My cat is fatter than Nina’s cat.',
#      '한글': '내 고양이는 Nina의 고양이보다 더 뚱뚱해.'},
#     {'영문': 'This meat has a lot of fat.', '한글': '이 고기는 지방이 많다.'}]},
#   {'단어': 'thin',
#    '단어 뜻': ['마른'],
#    '품사': '형용사',
#    '예문': [{'영문': 'Phil is thinner than Emily.',
#      '한글': 'Phil은 Emily보다 더 말랐어.'}]}],
#  'category_222': [{'단어': 'give',
#    '단어 뜻': ['주다'],
#    '품사': '',
#    '예문': [{'영문': 'Give me the pen.', '한글': '나에게 그 펜을 줘.'}]},
#   {'단어': 'provide',
#    '단어 뜻': ['제공하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’ll provide the tent if you come here.',
#      '한글': '네가 여기에 오면 내가 텐트를 제공할개.'}]},
#   {'단어': 'bring',
#    '단어 뜻': ['가지고 오\n다', '가져오다'],
#    '품사': '동사',
#    '예문': [{'영문': 'He is bringing a ring.', '한글': '그는 반지를 가져오고 있어.'},
#     {'영문': 'Bring the brush.', '한글': '빗자루를 가져와.'},
#     {'영문': 'Bring me some water, please.', '한글': '제게 물을 좀 가져다 주세요.'},
#     {'영문': 'Bring the book.', '한글': '그 책을 가져와.'}]},
#   {'단어': 'create',
#    '단어 뜻': ['창조하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'We can create wonderful artworks with our imagination.',
#      '한글': '우리는 우리의 상상력으로 멋진 예술 작품을 창조할 수 있다.'}]},
#   {'단어': 'receive',
#    '단어 뜻': ['받다'],
#    '품사': '동사',
#    '예문': [{'영문': 'I received an e-mail from her yesterday.',
#      '한글': '나는 어제 그녀에게서 이메일을 받았어.'}]},
#   {'단어': 'satisfy',
#    '단어 뜻': ['만족시키다'],
#    '품사': '동사',
#    '예문': [{'영문': 'His new cell phone satisfies him.',
#      '한글': '그는 그의 새 휴대전화에 만족해.'},
#     {'영문': 'The result did not satisfy me.', '한글': '그 결과는 나를 만족시키지 못했어.'}]},
#   {'단어': 'gift',
#    '단어 뜻': ['선물'],
#    '품사': '명사',
#    '예문': [{'영문': 'It’s a birthday gift from my dad.',
#      '한글': '그것은 아빠가 주신 생일 선물이야.'},
#     {'영문': 'Here is my gift.', '한글': '여기 내 선물이야.'}]},
#   {'단어': 'propose',
#    '단어 뜻': ['제안하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'The president of school proposed some changes for school life.',
#      '한글': '학교 회장은 학교 생활을 위한 몇 가지 개선점을 제안했다.'}]},
#   {'단어': 'deliver',
#    '단어 뜻': ['배달하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'She delivers mail to people.', '한글': '그녀는 사람들에게 편지를 배달해.'}]},
#   {'단어': 'contain',
#    '단어 뜻': ['~이 들어 있다', '들어 있다'],
#    '품사': '동사',
#    '예문': [{'영문': 'It contains an elephant.', '한글': '거기에는 코끼리가 들어 있어.'},
#     {'영문': 'Many foods contain sugar.', '한글': '많은 음식들에는 설탕이 들어 있어.'}]},
#   {'단어': 'serve',
#    '단어 뜻': ['제공하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'The waiter served the starter.',
#      '한글': '웨이터가 전채 요리를 제공했어.'}]},
#   {'단어': 'make',
#    '단어 뜻': ['만들다'],
#    '품사': '',
#    '예문': [{'영문': 'I can make cookies.', '한글': '나는 쿠키를 만들 수 있어.'}]},
#   {'단어': 'share',
#    '단어 뜻': ['함께 쓰다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Share useful things instead of throwing them away.',
#      '한글': '쓸 만한 것들은 버리는 대신 나눠 써라.'}]}],
#  'category_223': [{'단어': 'photo',
#    '단어 뜻': ['사진'],
#    '품사': '',
#    '예문': [{'영문': 'These are her photos.', '한글': '이것들은 그녀의 사진이야.'}]},
#   {'단어': 'picture',
#    '단어 뜻': ['그림, 사진'],
#    '품사': '',
#    '예문': [{'영문': 'He is drawing a picture.', '한글': '그는 그림을 그리고 있어.'}]},
#   {'단어': 'camera',
#    '단어 뜻': ['카메라'],
#    '품사': '',
#    '예문': [{'영문': 'May I use your camera?', '한글': '네 카메라를 사용해도 될까?'},
#     {'영문': 'That is his camera.', '한글': '저것은 그의 카메라야.'}]}],
#  'category_224': [{'단어': 'apart',
#    '단어 뜻': ['떨어져'],
#    '품사': '부사',
#    '예문': [{'영문': 'The two buildings are far apart.',
#      '한글': '두 건물이 멀리 떨어져 있어.'}]},
#   {'단어': 'separate',
#    '단어 뜻': ['분리하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'Can you separate gold from sand?',
#      '한글': '모래에서 금을 분리할 수 있니?'}]},
#   {'단어': 'different',
#    '단어 뜻': ['다른'],
#    '품사': '형용사',
#    '예문': [{'영문': 'The students come from different school.',
#      '한글': '그 학생들은 다른 학교 출신이야.'},
#     {'영문': 'Jack’s uniform is different from ours.',
#      '한글': 'Jack의 체육복은 우리 것과 달라.'},
#     {'영문': 'They’re not the same. They’re different.',
#      '한글': '그들은 똑같지 않아. 달라.'}]},
#   {'단어': 'independent',
#    '단어 뜻': ['독립적인'],
#    '품사': 'adj.',
#    '예문': [{'영문': 'Jane is a very independent young woman.',
#      '한글': 'Jane은 아주 독립적인 젊은 여성이다.'}]},
#   {'단어': 'alone',
#    '단어 뜻': ['혼자'],
#    '품사': '형용사',
#    '예문': [{'영문': 'He was alone on the island.', '한글': '그는 섬에 혼자 있었어.'}]},
#   {'단어': 'together',
#    '단어 뜻': ['함께'],
#    '품사': '',
#    '예문': [{'영문': 'Let’s come together.', '한글': '함께 모이자.'}]}],
#  'category_225': [{'단어': 'forgive',
#    '단어 뜻': ['용서하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Please forgive me. It was my mistake.',
#      '한글': '제발 나를 용서해 줘. 그것은 내 실수였어.'}]},
#   {'단어': 'apologize to',
#    '단어 뜻': ['~에게 사과하다'],
#    '품사': 'phr.',
#    '예문': [{'영문': "He's going to apologize to her for his mistake.",
#      '한글': '그는 자신의 실수에 대해 그녀에게 사과할 것이다.'}]},
#   {'단어': 'excuse me',
#    '단어 뜻': ['실례합니다'],
#    '품사': '',
#    '예문': [{'영문': 'Excuse me. Where is the bank?', '한글': '실례합니다. 은행이 어디인가요?'},
#     {'영문': 'Excuse me. Where is the park?', '한글': '실례합니다. 공원은 어디에 있나요?'},
#     {'영문': 'Excuse me, where is the restroom?',
#      '한글': '실례합니다, 화장실이 어디에 있나요?'}]},
#   {'단어': 'sorry',
#    '단어 뜻': ['미안한'],
#    '품사': '',
#    '예문': [{'영문': 'I’m sorry.', '한글': '미안해.'}]}],
#  'category_226': [{'단어': 'mislead',
#    '단어 뜻': ['잘못 이끌다', '속이다'],
#    '품사': '동사',
#    '예문': [{'영문': 'The guide misled us, and we got lost.',
#      '한글': '안내인이 우리를 잘못 이끌어서 우리는 길을 잃었어.'},
#     {'영문': 'She lied to mislead people.', '한글': '그녀는 사람들을 속이려고 거짓말을 했다.'}]},
#   {'단어': 'misjudge',
#    '단어 뜻': ['잘못 판단하다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'I seem to have misjudged my neighbor.',
#      '한글': '나는 이웃을 잘못 판단했던 것 같다.'}]},
#   {'단어': 'lie',
#    '단어 뜻': ['눕다, 거짓\n말하다', '거짓말'],
#    '품사': '동사',
#    '예문': [{'영문': 'I’m lying on the floor.', '한글': '나는 바닥에 누워 있어.'},
#     {'영문': 'Judy’s nose is growing long because she told a lie to me.',
#      '한글': 'Judy는 나에게 거짓말을 했기 때문에 코가 길어지고 있어.'}]},
#   {'단어': 'misunderstand',
#    '단어 뜻': ['오해하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Don’t misunderstand me.', '한글': '나를 오해하지 마.'}]},
#   {'단어': 'misspell',
#    '단어 뜻': ['철자를 잘못 쓰다'],
#    '품사': 'v.',
#    '예문': [{'영문': 'I apologize for misspelling your name.',
#      '한글': '너의 이름 철자를 잘못 쓴 것에 대해 내가 사과할게.'}]}],
#  'category_227': [{'단어': 'tea',
#    '단어 뜻': ['티'],
#    '품사': '',
#    '예문': [{'영문': 'We want tea.', '한글': '우리는 차를 원해.'}]},
#   {'단어': 'coffee',
#    '단어 뜻': ['커피'],
#    '품사': '',
#    '예문': [{'영문': 'I want coffee.', '한글': '나는 커피를 원해.'}]},
#   {'단어': 'pot',
#    '단어 뜻': ['냄비'],
#    '품사': '명사',
#    '예문': [{'영문': 'First, put the onions in the pot.',
#      '한글': '먼저 냄비에 양파를 넣어.'}]}],
#  'category_228': [{'단어': 'fuel',
#    '단어 뜻': ['연료'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Engineers are doing an experiment on the car using eco-friendly fuel.',
#      '한글': '기술자들은 친환경 연료를 사용하는 자동차에 관한 실험을 하고 있다.'}]},
#   {'단어': 'gas',
#    '단어 뜻': ['가스'],
#    '품사': 'n.',
#    '예문': [{'영문': 'Making less trash helps to lower the emission of greenhouse gases.',
#      '한글': '쓰레기를 덜 만드는 것은 온실가스 배출을 줄이는 것에 도움이 된다.'}]},
#   {'단어': 'electricity',
#    '단어 뜻': ['전기, 전력'],
#    '품사': 'n.',
#    '예문': [{'영문': 'The automobile runs on electricity.',
#      '한글': '그 자동차는 전기로 움직인다.'}]},
#   {'단어': 'energy',
#    '단어 뜻': ['에너지'],
#    '품사': 'n.',
#    '예문': [{'영문': 'We can use solar energy to heat the house.',
#      '한글': '우리는 집을 데우기 위해 태양 에너지를 사용할 수 있다.'}]},
#   {'단어': 'oil',
#    '단어 뜻': ['기름'],
#    '품사': 'n.',
#    '예문': [{'영문': 'There is so much oil in the sea due to the ship accident.',
#      '한글': '선박 사고 때문에 바다에 너무 많은 기름이 있다.'}]}],
#  'category_229': [{'단어': 'happen',
#    '단어 뜻': ['일어난다'],
#    '품사': '동사',
#    '예문': [{'영문': 'What happened to you?', '한글': '네게 무슨 일이 일어났니?'}]},
#   {'단어': 'occur',
#    '단어 뜻': ['발생하다'],
#    '품사': '동사',
#    '예문': [{'영문': 'Where were you when the accident occurred?',
#      '한글': '그 사건이 발생했을 때 너는 어디에 있었니?'}]},
#   {'단어': 'appear',
#    '단어 뜻': ['나타나다'],
#    '품사': '동사',
#    '예문': [{'영문': 'One by one, the stars appeared in the sky.',
#      '한글': '하나씩, 별들이 하늘에 나타났어.'}]},
#   {'단어': 'act',
#    '단어 뜻': ['행동하다'],
#    '품사': '',
#    '예문': [{'영문': 'My cat acts like a dog.', '한글': '우리 고양이는 개처럼 행동을 해.'}]}]}

# %% [markdown]
# # 추출

# %%
words = [entry["단어"] for category in data.values() for entry in category]
words

output_path = "./extracted_words.json"
with open(output_path, "w",encoding="utf-8") as File:
    json.dump(words,File,ensure_ascii=False,indent=4)
